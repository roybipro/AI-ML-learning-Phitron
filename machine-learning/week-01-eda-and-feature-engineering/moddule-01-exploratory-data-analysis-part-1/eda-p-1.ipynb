# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data.csv')
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
# 3            4      yes  first
# 4            5       no  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(f"Total potential features: {df.shape[1]}")
print(f"Total sample data: {df.shape[0]}")
# Out:
# Total potential features: 12
# Total sample data: 891

# %%
df.sample(10)
# Out:
#      PassengerId Survived  Pclass                                 Name  \
# 839          840      yes   first                 Marechal, Mr. Pierre
# 196          197       no   third                  Mernagh, Mr. Robert
# 361          362       no  second            del Carlo, Mr. Sebastiano
# 344          345       no  second              Fox, Mr. Stanley Hubert
# 157          158       no   third                      Corn, Mr. Harry
# 546          547      yes  second    Beane, Mrs. Edward (Ethel Clarke)
# 776          777       no   third                     Tobin, Mr. Roger
# 538          539       no   third             Risien, Mr. Samuel Beard
# 717          718      yes  second  Troutt, Miss. Edwina Celia "Winnie"
# 135          136       no  second                   Richard, Mr. Emile
#
#         Sex   Age  SibSp  Parch           Ticket     Fare Cabin Embarked
# 839    male   NaN      0      0            11774  29.7000   C47        C
# 196    male   NaN      0      0           368703   7.7500   NaN        Q
# 361    male  29.0      1      0    SC/PARIS 2167  27.7208   NaN        C
# 344    male  36.0      0      0           229236  13.0000   NaN        S
# 157    male  30.0      0      0  SOTON/OQ 392090   8.0500   NaN        S
# 546  female  19.0      1      0             2908  26.0000   NaN        S
# 776    male   NaN      0      0           383121   7.7500   F38        Q
# 538    male   NaN      0      0           364498  14.5000   NaN        S
# 717  female  27.0      0      0            34218  10.5000  E101        S
# 135    male  23.0      0      0    SC/PARIS 2133  15.0458   NaN        C

# %% [markdown]
# ### 1.3 Input Screening

# %%
#missing value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# checking duplicate value
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 1.4 Statistical Profiling

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    str
#  2   Pclass       891 non-null    str
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(3), str(7)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### 1.5 Univariate Analysis (Categorical Value Analysis -1)

# %%
sns.countplot(data=df, x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
(df['Survived'].value_counts()/len(df))*100
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
survived_count = df['Survived'].value_counts()

plt.pie(survived_count, labels=survived_count.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x117dffcb0>,
#   <matplotlib.patches.Wedge at 0x118129f90>],
#  [Text(-0.39257494735793463, 1.0275626067091557, 'no'),
#   Text(0.3925749146953058, -1.0275626191877425, 'yes')],
#  [Text(-0.21413178946796432, 0.5604886945686304, '61.6%'),
#   Text(0.21413177165198496, -0.5604887013751322, '38.4%')])
