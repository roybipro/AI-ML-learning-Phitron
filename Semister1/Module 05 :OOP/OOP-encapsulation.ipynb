# %%
class Mobile:
    def __init__(self,name,model,iemi):
        self.__name = name
        self.__model = model
        self.__iemi =iemi #__ make private
        
    def charge(self):
        print("Phone id charging")
        
        
    def iemi_getter(self):
        return self.__iemi        
    
    def name_getter(self):
        return self.__name
       
    def model_getter(self):
        return self.__model
    
    def name_setter(self,name):
        self.__name = name
             
iphone = Mobile("Phone","17 pro","4h467rgbw7")


print(iphone.name_getter())

iphone.name_setter("Bipros")

print(iphone.name_getter())
# Out:
# Phone
# Bipros
