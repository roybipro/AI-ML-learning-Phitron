# %% [markdown]
# ### Filtering Based on String

# %%
import pandas as pd

data ={
    "Name": ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Heidi', 'Ivan', 'Judy',],
    "city": ['New York', 'Los Angeles', 'New Delhi', 'Houston', 'Newark', 'New Orleans', 'San Antonio', 'San Diego', 'Dallas', 'H Los Angeles'],
    "Department": ['HR', 'Finance', 'IT', 'Marketing', 'Sales', 'HR', 'Finance', 'IT', 'Marketing', 'Sales'],
    "Salary": [70000, 80000, 90000, 75000, 85000, 72000, 82000, 92000, 77000, 87000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name           city Department  Salary
# 0    Alice       New York         HR   70000
# 1      Bob    Los Angeles    Finance   80000
# 2  Charlie      New Delhi         IT   90000
# 3    David        Houston  Marketing   75000
# 4      Eve         Newark      Sales   85000
# 5    Frank    New Orleans         HR   72000
# 6    Grace    San Antonio    Finance   82000
# 7    Heidi      San Diego         IT   92000
# 8     Ivan         Dallas  Marketing   77000
# 9     Judy  H Los Angeles      Sales   87000

# %%
df.loc[df['city'].str.contains("New")]
# Out:
#       Name         city Department  Salary
# 0    Alice     New York         HR   70000
# 2  Charlie    New Delhi         IT   90000
# 4      Eve       Newark      Sales   85000
# 5    Frank  New Orleans         HR   72000

# %%
df.loc[df['city'].str.contains("new", case=False)] # case=False means it will ignore the case sensitivity. So it will match "New", "new", "NEW", etc.
# Out:
#       Name         city Department  Salary
# 0    Alice     New York         HR   70000
# 2  Charlie    New Delhi         IT   90000
# 4      Eve       Newark      Sales   85000
# 5    Frank  New Orleans         HR   72000

# %%
#start with "Los"
df.loc[df['city'].str.contains(r"^Los")] # ^ means starts with
# Out:
#   Name         city Department  Salary
# 1  Bob  Los Angeles    Finance   80000

# %%
#end with rk
df.loc[df['city'].str.contains(r"rk$")] # $ means ends with
# Out:
#     Name      city Department  Salary
# 0  Alice  New York         HR   70000
# 4    Eve    Newark      Sales   85000

# %%
#name start with vowel
df.loc[df['Name'].str.contains(r"^[AEIOUaeiou]")] # ^ means starts with and [AEIOUaeiou] means any of the characters in the brackets
# Out:
#     Name      city Department  Salary
# 0  Alice  New York         HR   70000
# 4    Eve    Newark      Sales   85000
# 8   Ivan    Dallas  Marketing   77000

# %%
#start with New or los
df.loc[df['city'].str.contains(r"(^New|Los)")] # ^ means starts with and (New|Los) means either New or Los
# Out:
# /var/folders/gg/nmkjyktn2ks12wkqpnyjr7mc0000gn/T/ipykernel_39647/3937092426.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['city'].str.contains(r"(^New|Los)")] # ^ means starts with and (New|Los) means either New or Los
#       Name           city Department  Salary
# 0    Alice       New York         HR   70000
# 1      Bob    Los Angeles    Finance   80000
# 2  Charlie      New Delhi         IT   90000
# 4      Eve         Newark      Sales   85000
# 5    Frank    New Orleans         HR   72000
# 9     Judy  H Los Angeles      Sales   87000

# %% [markdown]
#  #### 12.2 Adding new Column and Saving the File

# %%
import pandas as pd
df = pd.read_csv('student_completed_data.csv')

# %%
#adding a new columnn with constant value
df['Country'] = 'Bangladesh'
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH0001       Alif Rahman                  85.5             88.0
# 1    PH0002     Fatima Akhter                  66.5              NaN
# 2    PH0003     Imran Hossain                  78.0             78.0
# 3    PH0004  Jannatul Ferdous                  79.0             44.0
# 4    PH0005       Kamal Uddin                  65.0             98.0
#
#    Python Marks CompletionStatus EnrollmentDate FinishedDate Instructor  \
# 0          88.0        Completed     2024-09-01   2024-12-23  Ms. Salma
# 1           NaN      In Progress     2024-08-11   2024-11-07  Mr. Karim
# 2          76.0        Completed     2024-05-08   2024-08-08  Ms. Salma
# 3          44.0        Completed     2024-07-05   2024-09-23  Mr. Karim
# 4          98.0        Completed     2024-02-01   2024-04-17  Mr. David
#
#   Location     Country
# 0   Khulna  Bangladesh
# 1    Dhaka  Bangladesh
# 2    Dhaka  Bangladesh
# ...

# %%
#total marks
df['Total Marks'] = df['Data Structure Marks'] + df['Algorithm Marks'] + df['Python Marks']

# %%
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH0001       Alif Rahman                  85.5             88.0
# 1    PH0002     Fatima Akhter                  66.5              NaN
# 2    PH0003     Imran Hossain                  78.0             78.0
# 3    PH0004  Jannatul Ferdous                  79.0             44.0
# 4    PH0005       Kamal Uddin                  65.0             98.0
#
#    Python Marks CompletionStatus EnrollmentDate FinishedDate Instructor  \
# 0          88.0        Completed     2024-09-01   2024-12-23  Ms. Salma
# 1           NaN      In Progress     2024-08-11   2024-11-07  Mr. Karim
# 2          76.0        Completed     2024-05-08   2024-08-08  Ms. Salma
# 3          44.0        Completed     2024-07-05   2024-09-23  Mr. Karim
# 4          98.0        Completed     2024-02-01   2024-04-17  Mr. David
#
#   Location     Country  Total Marks
# 0   Khulna  Bangladesh        261.5
# 1    Dhaka  Bangladesh          NaN
# ...

# %%
import numpy as np
#A+ in Data Structure if marks >= 80
df['Data Structure Grade'] = np.where(df['Data Structure Marks'] >= 80, 'A+', np.where(df['Data Structure Marks'] >= 70, 'A', np.where(df['Data Structure Marks'] >= 60, 'B', np.where(df['Data Structure Marks'] >= 50, 'C', np.where(df['Data Structure Marks'] >= 40, 'D', 'F')))))
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH0001       Alif Rahman                  85.5             88.0
# 1    PH0002     Fatima Akhter                  66.5              NaN
# 2    PH0003     Imran Hossain                  78.0             78.0
# 3    PH0004  Jannatul Ferdous                  79.0             44.0
# 4    PH0005       Kamal Uddin                  65.0             98.0
#
#    Python Marks CompletionStatus EnrollmentDate FinishedDate Instructor  \
# 0          88.0        Completed     2024-09-01   2024-12-23  Ms. Salma
# 1           NaN      In Progress     2024-08-11   2024-11-07  Mr. Karim
# 2          76.0        Completed     2024-05-08   2024-08-08  Ms. Salma
# 3          44.0        Completed     2024-07-05   2024-09-23  Mr. Karim
# 4          98.0        Completed     2024-02-01   2024-04-17  Mr. David
#
#   Location     Country  Total Marks Data Structure Grade
# 0   Khulna  Bangladesh        261.5                   A+
# ...

# %%
#first Name
df['First Name'] = df['FullName'].str.split().str[0]
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH0001       Alif Rahman                  85.5             88.0
# 1    PH0002     Fatima Akhter                  66.5              NaN
# 2    PH0003     Imran Hossain                  78.0             78.0
# 3    PH0004  Jannatul Ferdous                  79.0             44.0
# 4    PH0005       Kamal Uddin                  65.0             98.0
#
#    Python Marks CompletionStatus EnrollmentDate FinishedDate Instructor  \
# 0          88.0        Completed     2024-09-01   2024-12-23  Ms. Salma
# 1           NaN      In Progress     2024-08-11   2024-11-07  Mr. Karim
# 2          76.0        Completed     2024-05-08   2024-08-08  Ms. Salma
# 3          44.0        Completed     2024-07-05   2024-09-23  Mr. Karim
# 4          98.0        Completed     2024-02-01   2024-04-17  Mr. David
#
#   Location     Country  Total Marks Data Structure Grade First Name
# ...

# %%
df.to_csv('new_data.csv')

# %% [markdown]
# ### 12.3 Checking Duplicates and Null Values in DF

# %%
import pandas as pd
data = {
    "Name": ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Bob', 'Grace', 'Heidi', 'David', 'Judy',],
    "city": ['New York', 'Los Angeles', 'New Delhi', 'Houston', 'Newark', 'New Orleans', 'San Antonio', 'San Diego', 'Dallas', 'H Los Angeles'],
    "score": [85, 90, 78, 92, 88, 95, 80, 91, 89, 94]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name           city  score
# 0    Alice       New York     85
# 1      Bob    Los Angeles     90
# 2  Charlie      New Delhi     78
# 3    David        Houston     92
# 4      Eve         Newark     88
# 5      Bob    New Orleans     95
# 6    Grace    San Antonio     80
# 7    Heidi      San Diego     91
# 8    David         Dallas     89
# 9     Judy  H Los Angeles     94

# %%
#Unique and nunique
df['Name'].unique() # unique values in the Name column
len(df['Name'].unique()) # number of unique values in the Name column
# Out:
# 8

# %%
df1 = pd.read_csv('new_data.csv')
print(df1.head())
# Out:
#    Unnamed: 0 StudentID          FullName  Data Structure Marks  \
# 0           0    PH0001       Alif Rahman                  85.5
# 1           1    PH0002     Fatima Akhter                  66.5
# 2           2    PH0003     Imran Hossain                  78.0
# 3           3    PH0004  Jannatul Ferdous                  79.0
# 4           4    PH0005       Kamal Uddin                  65.0
#
#    Algorithm Marks  Python Marks CompletionStatus EnrollmentDate FinishedDate  \
# 0             88.0          88.0        Completed     2024-09-01   2024-12-23
# 1              NaN           NaN      In Progress     2024-08-11   2024-11-07
# 2             78.0          76.0        Completed     2024-05-08   2024-08-08
# 3             44.0          44.0        Completed     2024-07-05   2024-09-23
# 4             98.0          98.0        Completed     2024-02-01   2024-04-17
#
#   Instructor Location     Country  Total Marks Data Structure Grade First Name
# ...

# %%
print(len(df1['Data Structure Marks'].unique())) # number of unique values in the Data Structure Marks column

print(df1['Data Structure Marks'].nunique()) # number of unique values in the Data Structure Marks column
# Out:
# 16
# 15

# %% [markdown]
# ### check null

# %%
df1[df1['Data Structure Marks'].isnull()]
# Out:
#     Unnamed: 0 StudentID     FullName  Data Structure Marks  Algorithm Marks  \
# 7            7    PH0008  Nadia Islam                   NaN              NaN
# 17          17    PH0018  Babul Ahmed                   NaN             78.0
# 20          20       NaN          NaN                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate FinishedDate Instructor  \
# 7           98.0      In Progress     2024-03-22   2024-05-01  Ms. Salma
# 17          78.0        Completed     2024-06-23   2024-09-20  Mr. David
# 20           NaN              NaN            NaN          NaN        NaN
#
#    Location     Country  Total Marks Data Structure Grade First Name
# 7    Khulna  Bangladesh          NaN                    F      Nadia
# 17    Dhaka  Bangladesh          NaN                    F      Babul
# 20      NaN  Bangladesh          NaN                    F        NaN

# %%
df1['Data Structure Marks'].isnull()# check if there are any missing values in the DataFrame
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20     True
# Name: Data Structure Marks, dtype: bool

# %% [markdown]
# ### 12.4 Handling Duplicates Values

# %%
import pandas as pd
data = {
    "Name": ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Bob', 'Alice', 'Heidi', 'David', 'Judy',],
    "city": ['New York', 'Los Angeles', 'New Delhi', 'Houston', 'Newark', 'Los Angeles', 'San Antonio', 'San Diego', 'Dallas', 'New York'],
    "score": [85, 90, 78, 92, 85, 90, 80, 91, 89, 94]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name         city  score
# 0    Alice     New York     85
# 1      Bob  Los Angeles     90
# 2  Charlie    New Delhi     78
# 3    David      Houston     92
# 4      Eve       Newark     85
# 5      Bob  Los Angeles     90
# 6    Alice  San Antonio     80
# 7    Heidi    San Diego     91
# 8    David       Dallas     89
# 9     Judy     New York     94

# %%
df.duplicated().sum() # number of duplicate rows in the DataFrame
# Out:
# np.int64(1)

# %%
# delete duplicate rows
df.drop_duplicates()
# Out:
#       Name         city  score
# 0    Alice     New York     85
# 1      Bob  Los Angeles     90
# 2  Charlie    New Delhi     78
# 3    David      Houston     92
# 4      Eve       Newark     85
# 6    Alice  San Antonio     80
# 7    Heidi    San Diego     91
# 8    David       Dallas     89
# 9     Judy     New York     94

# %%
# premanently delete duplicate rows
df.drop_duplicates(inplace=True)
df
# Out:
#       Name         city  score
# 0    Alice     New York     85
# 1      Bob  Los Angeles     90
# 2  Charlie    New Delhi     78
# 3    David      Houston     92
# 4      Eve       Newark     85
# 6    Alice  San Antonio     80
# 7    Heidi    San Diego     91
# 8    David       Dallas     89
# 9     Judy     New York     94

# %%
df
# Out:
#       Name         city  score
# 0    Alice     New York     85
# 1      Bob  Los Angeles     90
# 2  Charlie    New Delhi     78
# 3    David      Houston     92
# 4      Eve       Newark     85
# 6    Alice  San Antonio     80
# 7    Heidi    San Diego     91
# 8    David       Dallas     89
# 9     Judy     New York     94

# %%
# name er basis a delete duplicate rows
df.drop_duplicates(subset=['Name'],keep='last')
# Out:
#       Name         city  score
# 1      Bob  Los Angeles     90
# 2  Charlie    New Delhi     78
# 4      Eve       Newark     85
# 6    Alice  San Antonio     80
# 7    Heidi    San Diego     91
# 8    David       Dallas     89
# 9     Judy     New York     94

# %%
df.drop_duplicates(subset=['city'],keep='last')
# Out:
#       Name         city  score
# 1      Bob  Los Angeles     90
# 2  Charlie    New Delhi     78
# 3    David      Houston     92
# 4      Eve       Newark     85
# 6    Alice  San Antonio     80
# 7    Heidi    San Diego     91
# 8    David       Dallas     89
# 9     Judy     New York     94

# %% [markdown]
# ### 12.5 Handling Null Values

# %%
import pandas as pd

df = pd.read_csv('student_completed_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman                  85.5             88.0
# 1     PH0002     Fatima Akhter                  66.5              NaN
# 2     PH0003     Imran Hossain                  78.0             78.0
# 3     PH0004  Jannatul Ferdous                  79.0             44.0
# 4     PH0005       Kamal Uddin                  65.0             98.0
# 5     PH0006       Laila Begum                  90.0             13.0
# 6     PH0007    Mahmudul Hasan                  85.0             98.0
# 7     PH0008       Nadia Islam                   NaN              NaN
# 8     PH0009        Omar Faruq                  98.0             33.0
# 9     PH0010      Priya Sharma                  99.0              8.0
# 10    PH0011      Rahim Sheikh                  66.0             76.0
# 11    PH0012   Sadia Chowdhury                  78.0             57.0
# ...

# %%
df.dropna(how='all',inplace=True) #all values are NaN then drop that row anyway it will not drop any row because there is no row where all values are NaN

# %%
df.dropna(subset=['Python Marks','Algorithm Marks']) # drop rows where Python and Algorithm Marks are NaN
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman                  85.5             88.0
# 2     PH0003     Imran Hossain                  78.0             78.0
# 3     PH0004  Jannatul Ferdous                  79.0             44.0
# 4     PH0005       Kamal Uddin                  65.0             98.0
# 5     PH0006       Laila Begum                  90.0             13.0
# 6     PH0007    Mahmudul Hasan                  85.0             98.0
# 8     PH0009        Omar Faruq                  98.0             33.0
# 9     PH0010      Priya Sharma                  99.0              8.0
# 11    PH0012   Sadia Chowdhury                  78.0             57.0
# 13    PH0014        Urmi Akter                  98.0             78.0
# 14    PH0015      Wahiduzzaman                  37.0             67.0
# 15    PH0016      Ziaur Rahman                  34.0             88.0
# ...

# %%
df = pd.read_csv('student_completed_data.csv') # load your data into a DataFrame
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman                  85.5             88.0
# 1     PH0002     Fatima Akhter                  66.5              NaN
# 2     PH0003     Imran Hossain                  78.0             78.0
# 3     PH0004  Jannatul Ferdous                  79.0             44.0
# 4     PH0005       Kamal Uddin                  65.0             98.0
# 5     PH0006       Laila Begum                  90.0             13.0
# 6     PH0007    Mahmudul Hasan                  85.0             98.0
# 7     PH0008       Nadia Islam                   NaN              NaN
# 8     PH0009        Omar Faruq                  98.0             33.0
# 9     PH0010      Priya Sharma                  99.0              8.0
# 10    PH0011      Rahim Sheikh                  66.0             76.0
# 11    PH0012   Sadia Chowdhury                  78.0             57.0
# ...

# %%
df.fillna(0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman                  85.5             88.0
# 1     PH0002     Fatima Akhter                  66.5              0.0
# 2     PH0003     Imran Hossain                  78.0             78.0
# 3     PH0004  Jannatul Ferdous                  79.0             44.0
# 4     PH0005       Kamal Uddin                  65.0             98.0
# 5     PH0006       Laila Begum                  90.0             13.0
# 6     PH0007    Mahmudul Hasan                  85.0             98.0
# 7     PH0008       Nadia Islam                   0.0              0.0
# 8     PH0009        Omar Faruq                  98.0             33.0
# 9     PH0010      Priya Sharma                  99.0              8.0
# 10    PH0011      Rahim Sheikh                  66.0             76.0
# 11    PH0012   Sadia Chowdhury                  78.0             57.0
# ...

# %%
df.fillna({'FullName': 'Unknown'}, inplace=True)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman                  85.5             88.0
# 1     PH0002     Fatima Akhter                  66.5              NaN
# 2     PH0003     Imran Hossain                  78.0             78.0
# 3     PH0004  Jannatul Ferdous                  79.0             44.0
# 4     PH0005       Kamal Uddin                  65.0             98.0
# 5     PH0006       Laila Begum                  90.0             13.0
# 6     PH0007    Mahmudul Hasan                  85.0             98.0
# 7     PH0008       Nadia Islam                   NaN              NaN
# 8     PH0009        Omar Faruq                  98.0             33.0
# 9     PH0010      Priya Sharma                  99.0              8.0
# 10    PH0011      Rahim Sheikh                  66.0             76.0
# 11    PH0012   Sadia Chowdhury                  78.0             57.0
# ...

# %%
df.fillna({'Python Marks': df['Python Marks'].mean(), 'Algorithm Marks': df['Algorithm Marks'].mean(), 'Data Structure Marks': df['Data Structure Marks'].mean()}, inplace=True)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %% [markdown]
# ### 12.6 Statistical Functions in Pandas

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
df.dropna() # drop rows where any value is NaN
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
print('Total Marks',df['Data Structure Marks'].sum()) # sum of the Data Structure Marks column
print('Average Marks',df['Data Structure Marks'].mean()) # mean of the Data Structure Marks column
print('Maximum Marks',df['Data Structure Marks'].max()) # max of the Data Structure Marks column
print('Minimum Marks',df['Data Structure Marks'].min()) # min of the Data Structure Marks column
# Out:
# Total Marks 1494.5000000000002
# Average Marks 71.16666666666667
# Maximum Marks 99.0
# Minimum Marks 27.0

# %%
# mode > highest frequency value
print('Mode Marks',df['Data Structure Marks'].mode()) # mode of the Data Structure Marks column
# Out:
# Mode Marks 0    71.166667
# Name: Data Structure Marks, dtype: float64

# %%
#standard deviation
print('Standard Deviation Marks',df['Data Structure Marks'].std()) # standard deviation of
# Out:
# Standard Deviation Marks 20.026232796010337

# %%
# corelation matrix
print('Correlation Matrix')
df[['Python Marks', 'Algorithm Marks']].corr()
# Out:
# Correlation Matrix
#                  Python Marks  Algorithm Marks
# Python Marks         1.000000         0.788583
# Algorithm Marks      0.788583         1.000000

# %%
#sum in diffrent column 
df[['Data Structure Marks', 'Algorithm Marks']].sum()
# Out:
# Data Structure Marks    1494.50
# Algorithm Marks         1401.75
# dtype: float64

# %%
#sum in diffrent row
df[['Data Structure Marks', 'Algorithm Marks']].sum(axis=1)
# Out:
# 0     173.500000
# 1     133.250000
# 2     156.000000
# 3     123.000000
# 4     163.000000
# 5     103.000000
# 6     183.000000
# 7     137.916667
# 8     131.000000
# 9     107.000000
# 10    142.000000
# 11    135.000000
# 12    141.750000
# 13    176.000000
# 14    104.000000
# 15    122.000000
# 16     93.750000
# 17    149.166667
# 18    132.000000
# 19    152.000000
# 20    137.916667
# dtype: float64

# %%
df['Total Marks'] = df.iloc[::,2:5].sum(axis=1)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks  Total Marks
# count             21.000000        21.000000     21.000000    21.000000
# mean              71.166667        66.750000     64.750000   202.666667
# std               20.026233        24.422326     25.825375    42.379904
# min               27.000000         8.000000      8.000000   115.000000
# 25%               65.000000        66.750000     57.000000   171.000000
# 50%               71.166667        67.000000     64.750000   206.750000
# 75%               85.000000        78.000000     87.000000   232.000000
# max               99.000000        98.000000     98.000000   264.000000

# %% [markdown]
# ### 12.7 Apply Function in DF

# %%
# min max scaling

mn = df['Total Marks'].min()
mx = df['Total Marks'].max()

df['Scaled Marks'] = df['Total Marks'].apply(lambda x: (x - mn) / (mx - mn))

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
#custom buid function

def greading_system(marks):
    if marks >= 260:
        return 'A+'
    elif marks >= 250:
        return 'A'
    elif marks >= 240:
        return 'A-'
    else:
        return 'F'
    
df['Grade'] = df['Total Marks'].apply(greading_system)

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
def marking_system(df):
    a = df['Data Structure Marks']*2
    b = df['Python Marks']*3
    c = df['Algorithm Marks']*4
    
    return a + b + c

df['Exceptional Marks'] = df.apply(marking_system, axis=1)

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %% [markdown]
# ### 12.8 DateTime and Timedelta

# %%
df['EnrollmentDate'] = pd.to_datetime(df['EnrollmentDate'])
df['EnrollmentDate']
# Out:
# 0    2024-09-01
# 1    2024-08-11
# 2    2024-05-08
# 3    2024-07-05
# 4    2024-02-01
# 5    2024-09-07
# 6    2024-06-07
# 7    2024-03-22
# 8    2024-02-12
# 9    2024-06-19
# 10   2024-03-14
# 11   2024-08-04
# 12   2024-06-07
# 13   2024-01-04
# 14   2024-02-22
# 15   2024-03-23
# 16   2024-01-18
# 17   2024-06-23
# 18   2024-04-19
# 19   2024-07-21
# 20          NaT
# Name: EnrollmentDate, dtype: datetime64[us]

# %%
df['Enrolment Year'] = df['EnrollmentDate'].dt.year
df['Enrolment Month'] = df['EnrollmentDate'].dt.month
df['Enrolment Day'] = df['EnrollmentDate'].dt.day

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %%
df['FinishedDate'] = pd.to_datetime(df['FinishedDate'])
df['Total time taken to complete'] = (df['FinishedDate'] - df['EnrollmentDate']).dt.days

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH0001       Alif Rahman             85.500000            88.00
# 1     PH0002     Fatima Akhter             66.500000            66.75
# 2     PH0003     Imran Hossain             78.000000            78.00
# 3     PH0004  Jannatul Ferdous             79.000000            44.00
# 4     PH0005       Kamal Uddin             65.000000            98.00
# 5     PH0006       Laila Begum             90.000000            13.00
# 6     PH0007    Mahmudul Hasan             85.000000            98.00
# 7     PH0008       Nadia Islam             71.166667            66.75
# 8     PH0009        Omar Faruq             98.000000            33.00
# 9     PH0010      Priya Sharma             99.000000             8.00
# 10    PH0011      Rahim Sheikh             66.000000            76.00
# 11    PH0012   Sadia Chowdhury             78.000000            57.00
# ...

# %% [markdown]
# ### 12.9 Pandas Group By

# %%
group = df.groupby('Instructor')

# %%
df.drop(columns=['StudentID', 'FullName','CompletionStatus'], inplace=True)

# %%
group = df.groupby('Instructor')

# %%
group.sum()
# Out:
#             Data Structure Marks  Algorithm Marks  Python Marks  \
# Instructor
# Mr. David             647.166667           573.50         514.5
# Mr. Karim             507.500000           440.75         427.5
# Ms. Salma             268.666667           320.75         353.0
#
#                                                      Location  Total Marks  \
# Instructor
# Mr. David   SylhetKhulnaChattogramDhakaDhakaSylhetRajshahi...  1735.166667
# Mr. Karim            DhakaKhulnaDhakaSylhetSylhetSylhetKhulna  1375.750000
# Ms. Salma                           KhulnaDhakaKhulnaRajshahi   942.416667
#
#             Scaled Marks        Grade  Exceptional Marks  Enrolment Year  \
# Instructor
# Mr. David       4.699105  A+FFFFA+FFF        5131.833333         18216.0
# Mr. Karim       3.830537      FFFFFFF        4060.500000         14168.0
# Ms. Salma       3.237696        A+FFF        2879.333333          8096.0
#
# ...

# %%
group.min()
# Out:
#             Data Structure Marks  Algorithm Marks  Python Marks    Location  \
# Instructor
# Mr. David                   27.0             8.00           8.0  Chattogram
# Mr. Karim                   55.0            33.00          33.0       Dhaka
# Ms. Salma                   34.0            66.75          76.0       Dhaka
#
#             Total Marks  Scaled Marks Grade  Exceptional Marks  \
# Instructor
# Mr. David         115.0      0.000000    A+              254.0
# Mr. Karim         164.0      0.328859     F              427.0
# Ms. Salma         213.0      0.657718    A+              693.0
#
#             Enrolment Year  Enrolment Month  Enrolment Day  \
# Instructor
# Mr. David           2024.0              1.0            1.0
# Mr. Karim           2024.0              2.0            4.0
# Ms. Salma           2024.0              3.0            1.0
#
#             Total time taken to complete
# Instructor
# Mr. David                           43.0
# ...

# %%
group.max()
# Out:
#             Data Structure Marks  Algorithm Marks  Python Marks  Location  \
# Instructor
# Mr. David                   99.0             98.0          98.0    Sylhet
# Mr. Karim                   98.0             87.0          87.0    Sylhet
# Ms. Salma                   85.5             88.0          98.0  Rajshahi
#
#             Total Marks  Scaled Marks Grade  Exceptional Marks  \
# Instructor
# Mr. David         264.0      1.000000     F              816.0
# Mr. Karim         239.0      0.832215     F              739.0
# Ms. Salma         261.5      0.983221     F              787.0
#
#             Enrolment Year  Enrolment Month  Enrolment Day  \
# Instructor
# Mr. David           2024.0              9.0           23.0
# Mr. Karim           2024.0              8.0           21.0
# Ms. Salma           2024.0              9.0           23.0
#
#             Total time taken to complete
# Instructor
# Mr. David                          115.0
# ...

# %%
group.first()
# Out:
#             Data Structure Marks  Algorithm Marks  Python Marks Location  \
# Instructor
# Mr. David                   65.0            98.00         98.00   Sylhet
# Mr. Karim                   66.5            66.75         64.75    Dhaka
# Ms. Salma                   85.5            88.00         88.00   Khulna
#
#             Total Marks  Scaled Marks Grade  Exceptional Marks  \
# Instructor
# Mr. David         261.0      0.979866    A+             816.00
# Mr. Karim         198.0      0.557047     F             594.25
# Ms. Salma         261.5      0.983221    A+             787.00
#
#             Enrolment Year  Enrolment Month  Enrolment Day  \
# Instructor
# Mr. David           2024.0              2.0            1.0
# Mr. Karim           2024.0              8.0           11.0
# Ms. Salma           2024.0              9.0            1.0
#
#             Total time taken to complete
# Instructor
# Mr. David                           76.0
# Mr. Karim                           88.0
# ...

# %%
group.last()
# Out:
#             Data Structure Marks  Algorithm Marks  Python Marks  Location  \
# Instructor
# Mr. David              71.166667             78.0          78.0     Dhaka
# Mr. Karim              65.000000             87.0          87.0    Khulna
# Ms. Salma              34.000000             88.0          91.0  Rajshahi
#
#             Total Marks  Scaled Marks Grade  Exceptional Marks  \
# Instructor
# Mr. David    227.166667      0.752796     F         688.333333
# Mr. Karim    239.000000      0.832215     F         739.000000
# Ms. Salma    213.000000      0.657718     F         693.000000
#
#             Enrolment Year  Enrolment Month  Enrolment Day  \
# Instructor
# Mr. David           2024.0              6.0           23.0
# Mr. Karim           2024.0              7.0           21.0
# Ms. Salma           2024.0              3.0           23.0
#
#             Total time taken to complete
# Instructor
# Mr. David                           89.0
# ...

# %% [markdown]
# ### 12.10 Group by Example

# %%
mean_marks = group['Total Marks'].mean()

mean_marks
# Out:
# Instructor
# Mr. David    192.796296
# Mr. Karim    196.535714
# Ms. Salma    235.604167
# Name: Total Marks, dtype: float64

# %%
df['Total Marks'] = df['Total Marks'].fillna(df['Instructor'].map(mean_marks))

df
# Out:
#     Data Structure Marks  Algorithm Marks  Python Marks Instructor  \
# 0              85.500000            88.00         88.00  Ms. Salma
# 1              66.500000            66.75         64.75  Mr. Karim
# 2              78.000000            78.00         76.00  Ms. Salma
# 3              79.000000            44.00         44.00  Mr. Karim
# 4              65.000000            98.00         98.00  Mr. David
# 5              90.000000            13.00         13.00  Mr. David
# 6              85.000000            98.00         33.00  Mr. David
# 7              71.166667            66.75         98.00  Ms. Salma
# 8              98.000000            33.00         33.00  Mr. Karim
# 9              99.000000             8.00          8.00  Mr. David
# 10             66.000000            76.00         64.75  Mr. Karim
# 11             78.000000            57.00         57.00  Mr. Karim
# 12             75.000000            66.75         64.75  Mr. David
# ...
