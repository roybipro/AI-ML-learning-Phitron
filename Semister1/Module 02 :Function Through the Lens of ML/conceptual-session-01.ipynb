# %%
m = int(input("Enter a number: "))

if m>0:
    print("Positive")
elif m<0:
    print("Negative")
else:
    print("Zero")

# %%
# list of number sum of even number and count even number

numbers = list(map(int,input("input numbrs").split()))

even_sum = 0
even_count = 0

for num in numbers:
    if num%2 == 0 :
        even_sum += num
        even_count += 1

# %%
even_count
# Out:
# 2

# %% [markdown]
# ## Dictionary

# %%
#Count frequency of each element in 

numbers = input().split()

freq ={}

for num in numbers:
    num = int(num)
    
    if num in freq:
        freq[num] +=1
        
    else:

# %%
import numpy as np
import pandas as pd


#create numpy array

names = np.array(["Alice","BOB","Charlie","Devid"])
scores = np.array([65,66,47,55])

data ={
    "Name" : names,
    "Score" : scores
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Sxore
# 0    Alice     65
# 1      BOB     66
# 2  Charlie     47
# 3    Devid     55

# %% [markdown]
# ## Iterator

# %% [markdown]
# ## Generator

# %% [markdown]
# np.arrange()

# %% [markdown]
# ## Filter
